# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3*X + np.random.randn(100, 1)

# %% [markdown]
# $y = wx + b$

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X, y)

# %% [markdown]
# ## Cost Function

# %%
def J(w, X, y):
    predictions = X.dot(w)
    cost = np.sum(np.square(predictions - y))
    return cost

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(X, y, learning_rate=0.001, iterations=100):
    w = np.random.randn(X.shape[1], 1)
    cost_history = np.zeros(iterations)
    w_history = np.zeros((iterations, 2))
    for i in range(iterations):
        prediction = np.dot(X, w)
        w = w - learning_rate * (X.T.dot(prediction - y))
        w_history[i, :] = w.T
        cost_history[i] = J(w, X, y)      
    return w, cost_history, w_history

# %%
X_b = np.c_[np.ones((len(X), 1)), X]

# %%
w, cost_hist, w_hist = gradient_descent(X_b, y)

# %% [markdown]
# ### Cost function plot

# %%
plt.plot(cost_hist)

# %%
w
# Out:
# array([[3.32869756],
#        [3.30180066]])

# %%
y_prime = w[0] * X_b[:, 0]+ w[1] * X_b[:, 1]

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X, y)
plt.plot(X, y_prime, 'red')
